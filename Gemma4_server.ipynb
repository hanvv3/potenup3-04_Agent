# %%
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent

# %%
model = ChatOpenAI(
    model = 'google/gemma-4-26B-A4B-it',
    base_url="http://100.95.34.69:8001/v1",
    api_key='dummy',
)



agent = create_agent(model = model, tools=[])

# %%
response = agent.invoke({
    "messages": [
        {"role": "user", "content": "안녕하세요! 자기소개를 해주세요."}
    ]
})

print(f"{response['messages'][-1].content}")
# Out:
# 안녕하세요! 만나서 반갑습니다. 😊
#
# 저는 사용자의 질문에 답변하고, 다양한 작업을 도와드리는 **인공지능 언어 모델**입니다.
#
# **제가 할 수 있는 일들은 다음과 같아요:**
#
# 1.  **질문 답변:** 궁금한 지식, 역사, 과학, 상식 등 무엇이든 물어보시면 답변해 드립니다.
# 2.  **글쓰기 및 창작:** 에세이, 이메일, 시, 소설, 보고서 작성은 물론 문장 교정이나 요약도 가능합니다.
# 3.  **언어 번역 및 학습:** 다양한 외국어를 번역하거나, 외국어 공부를 도와드릴 수 있습니다.
# 4.  **코딩 및 기술 지원:** 프로그래밍 코드 작성, 오류 수정(디버깅), 알고리즘 설명 등을 할 수 있습니다.
# 5.  **아이디어 브레인스토밍:** 프로젝트 아이디어, 여행 계획, 선물 추천 등 창의적인 아이디어가 필요할 때 도움을 드립니다.
#
# **저를 사용하는 팁!**
# *   질문을 구체적으로 해주실수록 더 정확한 답변을 드릴 수 있습니다.
# *   "~처럼 말해줘", "~의 입장에서 설명해줘"와 같이 **역할(페르소나)**을 지정해주시면 더 재미있고 유용한 답변을 얻을 수 있습니다.
#
# 무엇을 도와드릴까요? 궁금한 점이 있다면 언제든 편하게 말씀해 주세요!
