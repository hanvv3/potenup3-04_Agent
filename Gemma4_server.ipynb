# %%
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent

# %%
model = ChatOpenAI(
    model = 'google/gemma-4-26B-A4B-it',
    base_url="http://100.95.34.69:8001/v1",
    api_key='dummy',
)



agent = create_agent(model = model, tools=[])

# %%
response = agent.invoke({
    "messages": [
        {"role": "user", "content": "안녕하세요! 자기소개를 해주세요."}
    ]
})

print(f"{response['messages'][-1].content}")
# Out:
# 안녕하세요! 만나서 반갑습니다.
#
# 저는 사용자의 질문에 답하고, 다양한 작업을 도울 수 있도록 학습된 **대규모 언어 모델**입니다. 구체적으로 저에 대해 소개해 드릴게요.
#
# **✨ 제가 할 수 있는 일들은 다음과 같아요:**
#
# 1.  **질문에 답변하기:** 일상적인 궁금증부터 과학, 역사, 수학 등 전문적인 지식까지 폭넓은 질문에 답해 드립니다.
# 2.  **글쓰기 및 창작:** 이메일 작성, 블로그 포스팅, 시, 소설 쓰기, 보고서 작성 등 다양한 형태의 글을 대신 써드리거나 교정해 드립니다.
# 3.  **언어 번역 및 학습:** 다양한 언어 간의 번역을 돕고, 외국어 학습을 위한 연습 상대가 되어 드릴 수 있습니다.
# 4.  **코딩 및 기술 지원:** 프로그래밍 코드를 작성하거나, 오류(디버깅)를 찾아내고, 복잡한 기술 개념을 설명해 드립니다.
# 5.  **요약 및 분석:** 긴 글을 핵심 위주로 요약하거나, 데이터를 바탕으로 분석적인 의견을 제시합니다.
# 6.  **아이디어 브레인스토밍:** 새로운 프로젝트, 유튜브 콘텐츠 주제, 선물 아이디어 등 창의적인 아이디어가 필요할 때 함께 고민해 드립니다.
#
# **💡 저를 효과적으로 사용하는 팁:**
#
# *   **구체적으로 요청해 주세요:** "글 써줘"보다는 "20대 직장인을 대상으로 한 경제 뉴스레터 초안을 작성해줘"라고 말씀하시면 훨씬 만족스러운 결과를 얻으실 수 있습니다.
# *   **역할을 지정해 주세요:** "너는 전문 요리사야", "너는 친절한 수학 선생님이야"처럼 저에게 역할을 부여하면 그 상황에 맞는 말투와 지식 수준으로 대화할 수 있습니다.
# *   **추가 질문을 해주세요:** 답변이 부족하다면 "조금 더 자세히 설명해줘" 또는 "다른 예시를 들어줘"라고 요청해 주세요.
#
# 저는 완벽하지 않을 수 있지만, 사용님과 대화하며 계속해서 배우고 발전해 나가고 싶습니다. 무엇을 도와드릴까요? 궁금한 점이 있다면 언제든 편하게 말씀해 주세요! 😊
